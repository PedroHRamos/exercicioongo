# %%
import pymongo
from pymongo import MongoClient

# %%
# !python --version
# Out:
# Python 3.8.3

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\peped\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in c:\users\peped\anaconda3\lib\site-packages (from pymongo[srv]) (1.16.0)

# %%
pymongo.version
# Out:
# '3.11.0'

# %%
client = pymongo.MongoClient("mongodb+srv://admin:admin@cluster0.0vz9s.mongodb.net/anatel?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['anatel', 'admin', 'local']

# %%
db = client.anatel

# %%
# 1. Quantos documentos possui a coleção minas?
db.minas.count_documents({})
# Out:
# 529706

# %%
# 2. Mostre os 5 primeiros documentos da coleção.
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fb313248277bf3cb4ad76cd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': '9'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76cb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76f6'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Resposta de solicitação',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76e7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76ee'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '9'}]

# %%
# 3. Selecione o documento que possui o maior número de solicitações QtdeSolic na Anatel.
from bson.son import SON
import pprint
parametro = [ {"$group": { "_id": "null", "maxQuantity": {"$max": "$QtdeSolic"}  } }]
pprint.pprint(list(db.minas.aggregate(parametro)))
# Out:
# [{'_id': 'null', 'maxQuantity': '99'}]

# %%
#4 - Qual é o menor número de solicitações QtdeSolic na Anatel?
parametro = [ {"$group": { "_id": "null", "minQuantity": {"$min": "$QtdeSolic"}  } }]
pprint.pprint(list(db.minas.aggregate(parametro)))
# Out:
# [{'_id': 'null', 'minQuantity': 1}]

# %%
#5 - Mostre todos os documentos com o menor número de solicitações QtdeSolic na Anatel.
list(db.minas.find({'QtdeSolic': 1}))
# Out:
# [{'_id': ObjectId('5fb313728277bf3cb4adc67c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc67d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc67e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc67f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc680'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc684'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc687'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc688'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc689'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc68c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc68f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc692'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc693'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc698'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc69a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio Comunitária',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc69b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc69e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6a0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6a5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6a7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6a8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Licenciamento e instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ab'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Resposta de solicitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ac'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ad'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ae'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6b0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6b1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6b2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6b3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6b6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6b8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6bb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6bd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6be'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6bf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6c5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6cf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6d0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6d4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6d7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6d8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6dc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6dd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6df'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Prestadoras',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6e9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6eb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ee'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ef'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Limitado Privado',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc6ff'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc703'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc706'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc709'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc70a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Atuação da Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc70c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc70d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc70e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc710'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc712'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc714'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc715'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc717'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc71b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc71c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'GVT',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc71d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc71f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc722'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc723'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc729'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc730'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc731'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc732'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc734'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc735'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc738'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc73b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc73d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc742'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc746'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc74a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc74d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc74e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc752'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc757'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc759'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc75a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interrupções no Serviço de Localidades',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc75d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc762'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc763'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc766'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc76d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc77a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc77e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc787'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc788'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc798'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc79c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7a2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7a4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7a5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7a7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7a8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7b5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7b7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7bb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7bd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7bf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7c1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7ca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7cb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Contrato de prestação de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7cc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7d7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313728277bf3cb4adc7d8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
# ...
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdc8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdc9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdcb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdcc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Central de Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'MMDS (Via Microondas)',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Sala do Cidadão',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Documentos emitidos pela Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdd9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcddb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdde'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Produtos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcddf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Definição',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Portal Anatel',
#   'Motivo': 'Link Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcde7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdec'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdef'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdf9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdfb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdfd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdfe'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adcdff'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adce01'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adce02'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adce06'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb313738277bf3cb4adce07'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  ...]

# %%
#6) Mostre as contagens de solicitações QtdeSolic por tipo de serviço Servico, em ordem decrescente pelas contagens
parametro3 = [ {"$group": { "_id": {"Servico": "$Servico"}, "count": {"$sum": '$QtdeSolic'}  }}, { "$sort" : { "count" : -1 } } ]
pprint.pprint(list(db.minas.aggregate(parametro3)))
# Out:
# [{'_id': {'Servico': 'Móvel Pessoal'}, 'count': 1082677},
#  {'_id': {'Servico': 'Celular Pós-Pago'}, 'count': 812191},
#  {'_id': {'Servico': 'Serviço Telefônico Fixo Comutado - STFC'},
#   'count': 532895},
#  {'_id': {'Servico': 'Telefone Fixo'}, 'count': 514959},
#  {'_id': {'Servico': 'TV por Assinatura'}, 'count': 394184},
#  {'_id': {'Servico': 'Banda Larga Fixa'}, 'count': 349265},
#  {'_id': {'Servico': 'Celular Pré-Pago'}, 'count': 307646},
#  {'_id': {'Servico': 'Serviço de Comunicação Multimídia'}, 'count': 254742},
#  {'_id': {'Servico': 'Serviços da Anatel'}, 'count': 46939},
#  {'_id': {'Servico': 'Radiodifusão (Rádio e TV)'}, 'count': 6493},
#  {'_id': {'Servico': 'Outros'}, 'count': 2972},
#  {'_id': {'Servico': 'Rádio do Cidadão (PX)'}, 'count': 2963},
#  {'_id': {'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT'},
#   'count': 2824},
#  {'_id': {'Servico': 'Radioamador (PY)'}, 'count': 2810},
#  {'_id': {'Servico': 'Troncalizado (Trunking)'}, 'count': 2286},
#  {'_id': {'Servico': 'Limitado Privado'}, 'count': 1020},
#  {'_id': {'Servico': 'Serviço Móvel Aeronáutico'}, 'count': 153},
#  {'_id': {'Servico': 'Radiochamada (Paging)'}, 'count': 25},
#  {'_id': {'Servico': 'Serviço Móvel Marítimo'}, 'count': 20}]

# %%
# 7) Mostre todos os documentos com atributo Tipo igual a "Reclamação".
list(db.minas.find({'$Tipo': 'Reclamação'}))
# Out:
# [{'_id': ObjectId('5fb313248277bf3cb4ad76cd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': '9'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76cb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7700'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7704'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d5'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '10'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76dd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76cc'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76f7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7702'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76ca'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76f9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76fb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76df'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76dc'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d1'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '12'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76cf'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76fe'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76da'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76c8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76e2'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76e0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '5'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76c9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76db'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '7'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76fc'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76c7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76ce'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '29'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d2'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d6'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76fa'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76fd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76ff'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76e1'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cartão Telefônico',
#   'UF': 'MG',
#   'QtdeSolic': '11'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '15'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d3'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76f8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76d4'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad76de'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7701'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7703'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7707'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': '5'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad770a'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad770c'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7710'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad773d'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Limitado Privado',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad775e'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad776c'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7796'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '22'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad779d'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77bc'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '20'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77c2'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': '9'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ca'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Rede telefônica',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77e1'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': '21'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77e2'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77e6'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '8'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7749'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad778c'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '12'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad779f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': '17'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77b6'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': '30'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77b7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '75'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77b9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': '39'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77bd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '17'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77df'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '32'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77f7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77fd'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '153'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ff'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': '121'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7804'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad773e'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7763'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad776a'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7783'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7787'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '9'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77b8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77cb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '94'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77d0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7758'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7760'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7779'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cartão Telefônico',
#   'UF': 'MG',
#   'QtdeSolic': '10'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7789'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ab'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '194'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ba'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cópia de Documentos',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77c0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '52'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77d8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cópia de Documentos',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ee'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77fc'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '14'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77fe'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7740'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Atuação da Anatel',
#   'UF': 'MG',
#   'QtdeSolic': '6'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7741'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Central de Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad774b'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad774c'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '11'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad775f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7766'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7775'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '50'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7781'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7788'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7794'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': '6'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77a1'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '19'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ac'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': '8'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77bf'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Instalação',
#   'UF': 'MG',
#   'QtdeSolic': '47'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77e3'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77f5'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '46'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7713'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '5'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad774d'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '11'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7770'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '25'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad777a'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NEXTEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Troncalizado (Trunking)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7795'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77c1'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '117'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ef'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77f8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cópia de Documentos',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7714'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7761'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7769'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7793'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '22'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7798'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77a9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '6'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77b0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '111'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ce'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '13'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77cf'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77e0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77fb'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': '25'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7715'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad770b'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7705'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7750'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad7767'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'GVT',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad777f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad778e'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77b3'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77c3'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '57'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77c4'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': '8'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77db'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '14'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77ea'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77f4'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313248277bf3cb4ad77fa'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '1',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
# ...
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7ce3'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7ce8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7ced'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7cef'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d11'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d1e'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d28'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d58'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d8f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fax                 ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d91'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '3',
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d93'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '3',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d9f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '3',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '48'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7af4'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b18'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b19'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '11'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b23'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '4'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b28'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': '5'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b2e'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '5'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b7b'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b8b'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7bba'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7bd0'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7bd7'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7bdf'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '7'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c20'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': '17'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c37'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'SKY',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c3f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '3'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c6f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Contrato de prestação de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c7f'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Correspondência     ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c84'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Correspondência     ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c89'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Correspondência     ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7c9a'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7cac'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7cc6'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Outros',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7cd9'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7cf8'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': '5'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d31'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d56'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d57'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d63'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Serviço de Valor Adicionado',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d71'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Correspondência     ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d92'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '3',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': '2'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7d94'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '3',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b24'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '1'},
#  {'_id': ObjectId('5fb313258277bf3cb4ad7b40'),
#   'DataExtracao': '2016-04-28',
#   'Ano': '2006',
#   'Mes': '2',
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': '18'},
#  ...]

# %%
# 8) Quais diferentes valores encontramos em Tipo?
pprint.pprint(list(db.minas.distinct('Tipo')));
# Out:
# ['Denúncia', 'Elogio', 'Pedido de Informação', 'Reclamação', 'Sugestão']
